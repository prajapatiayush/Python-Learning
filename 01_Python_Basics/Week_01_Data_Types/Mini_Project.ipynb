# %%
# Investor Information
investor_name = "Ayush Prajapati"
account_balance = 250000.50
age = 22
is_active = True

portfolio = {
    "AAPL": 10,
    "MSFT": 8,
    "NVDA": 5
}

watchlist = ["TSLA", "AMZN", "META"]

print("===== Investor Profile =====")
print(f"Name: {investor_name}")
print(f"Age: {age}")
print(f"Balance: ₹{account_balance}")
print(f"Active Account: {is_active}")

print("\nPortfolio")
print(portfolio)

print("\nWatchlist")
print(watchlist)
# Out:
# ===== Investor Profile =====
# Name: Ayush Prajapati
# Age: 22
# Balance: ₹250000.5
# Active Account: True
#
# Portfolio
# {'AAPL': 10, 'MSFT': 8, 'NVDA': 5}
#
# Watchlist
# ['TSLA', 'AMZN', 'META']
